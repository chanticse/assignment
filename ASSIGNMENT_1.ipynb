# %% [markdown]
# <a href="https://colab.research.google.com/github/chanticse/assignment/blob/main/ASSIGNMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
#path 1 coordinates
coords_1=[[16.788505246771315, 80.8375875156031],
[16.63330062464972, 80.96667687527979],
[16.64908990456267, 81.0051290249707],
[16.69644993344935, 81.02435509981616],
[16.77798689280044, 81.21936243039154],
[16.80691096429985, 81.28528040129027],
[16.814798582399803, 81.40613001460457],
[16.843717040405206, 81.48852747822797],
[16.81216941281858, 81.58465785245527],
[16.76220827029443, 81.65057582335398],
[16.728016766088494, 81.76318569030596],
[16.791134744255423, 81.8675558108956],
[16.88314417976183, 81.92523403543198],
[16.820056812180773, 82.03784390238394],
[16.822685872370467, 82.10925503752424],
[16.846345772148766, 82.15869351569827],
[16.864745871536158, 82.18890591902685]]

#path 2 coordinates
coords_2=[[16.791134744255423, 80.85132042620702],
[16.680664560053692, 80.94195763619277],
[16.6938191284341, 80.98864953224601],
[16.68855740972763, 81.0051290249707],
[16.6859264960465, 81.02710168193694],
[16.738537882702133, 81.15344445949282],
[16.87000271387615, 81.30175989401492],
[16.922563086487905, 81.37317102915522],
[17.009255618997315, 81.51324671731498],
[17.040770241626486, 81.82086391484233],
[17.08278147360623, 81.91424770694886],
[17.019761082914346, 81.95544643876056],
[16.964600827059886, 82.01312466329694],
[16.96985488364343, 82.04608364874629],
[16.9251907204723, 82.07080288783331],
[16.91993541583876, 82.10376187328268],
[16.909424366695035, 82.13397427661127],
[16.8726310802021, 82.18890591902685]]

# %%
from branca.element import Figure
fig=Figure(width=550,height=350)
map=folium.Map(location=[16.864745871536158, 82.18890591902685],tiles='cartodbpositron',zoom_start=8)
fig.add_child(map)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
fig1=Figure(height=550,width=750)
map1=folium.Map(location=[16.864745697748052, 82.19433508024518],tiles='cartodbpositron',zoom_start=10)
fig1.add_child(map1)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
f1=folium.FeatureGroup("route1")
f2=folium.FeatureGroup("route 2")
line_1=folium.vector_layers.PolyLine(coords_1,popup='<b>route</b>',tooltip='route',color='green',weight=2).add_to(f1)
line_2=folium.vector_layers.PolyLine(coords_2,popup='<b>route</b>',tooltip='route',color='brown',weight=2).add_to(f2)
folium.Marker(location=[16.8726310802021, 82.19439908326844],popup='gorripudi',tooltip='Click here to see more details',icon=folium.Icon(color='pink',icon='none')).add_to(map)
folium.Marker(location=[16.791134744255423, 80.84033409772394],popup='NUZVID',tooltip='click',icon=folium.Icon(color='red',prefix='fa',icon='none')).add_to(map)
folium.Marker(location=[16.786982630214478, 80.85130401580827],popup='city grand',tooltip='Click',icon=folium.Icon(color='green',prefix='fa',icon='hotel')).add_to(map)
folium.Marker(location=[16.881848864790197, 80.87221132675624],popup='sri vaishnavi gas agency',tooltip='click',icon=folium.Icon(color='blue',prefix='fa',icon='tint')).add_to(map)
folium.Marker(location=[16.84606374481569, 80.84449050589633],popup='hp gas',tooltip='click',icon=folium.Icon(color='blue',prefix='fa',icon='tint')).add_to(map)
folium.Marker(location=[16.686499624354934, 81.01109616410317],popup='swagath dhaba garden restaurent',tooltip='click',icon=folium.Icon(color='red',prefix='fa',icon='cutlery')).add_to(map)
folium.Marker(location=[16.766725935866805, 81.10173337408891],popup='srinivasa hotel',tooltip='click',icon=folium.Icon(color='red',prefix='fa',icon='cutlery')).add_to(map)
folium.Marker(location=[16.92521731095003, 82.03122641743411],popup='hotel the retinue',tooltip='click',icon=folium.Icon(color='green',prefix='fa',icon='hotel')).add_to(map)
folium.Marker(location=[16.946237059322478, 81.51486897872748],popup='hotel moon light',tooltip='click',icon=folium.Icon(color='green',prefix='fa',icon='hotel')).add_to(map)
folium.Marker(location=[16.69024085881863, 81.00440468695278],popup='godavari gas private limited',tooltip='click',icon=folium.Icon(color='blue',prefix='fa',icon='tint')).add_to(map)
folium.Marker(location=[17.04759963057871, 81.69884081236326],popup='hp petrol pump',tooltip='click',icon=folium.Icon(color='blue',prefix='fa',icon='tint')).add_to(map)
f1.add_to(map)
f2.add_to(map)
map
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#two paths for nuzvid to gorripudi
f1=folium.FeatureGroup("route1")
f2=folium.FeatureGroup("route 2")
line_1=folium.vector_layers.PolyLine(coords_1,popup='<b>route</b>',tooltip='route',color='green',weight=2).add_to(f1)
line_2=folium.vector_layers.PolyLine(coords_2,popup='<b>route</b>',tooltip='route',color='brown',weight=2).add_to(f2)
f1.add_to(map1)
f2.add_to(map1)
map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
